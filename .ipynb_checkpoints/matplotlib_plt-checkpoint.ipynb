# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x= np.linspace(0,10,20)

# %%
x
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
y= np.cos(x)

# %%
y
# Out:
# array([ 1.        ,  0.8646637 ,  0.49528663, -0.00815095, -0.5093823 ,
#        -0.87273782, -0.99986712, -0.8563598 , -0.48105935,  0.02445069,
#         0.52334259,  0.88058   ,  0.99946853,  0.84782832,  0.46670422,
#        -0.04074393, -0.53716381, -0.88818817, -0.99880433, -0.83907153])

# %%
#plt is an alias of matplotlib
plt.scatter(x,y,c='black',edgecolors='r')
plt.xlabel("this my timepass data")
plt.ylabel("this is my another time pass")
plt.title("this is my graph")
# Out:
# Text(0.5, 1.0, 'this is my graph')

# %%
plt.plot(x,y,)

# %%
x=np.random.rand(25)
y=np.random.rand(25)

# %%
x,y
# Out:
# (array([0.38789276, 0.19354824, 0.27717489, 0.83327364, 0.45984288,
#         0.12666697, 0.15802698, 0.59305615, 0.54040013, 0.529568  ,
#         0.6070869 , 0.31358954, 0.50555699, 0.22815971, 0.17990205,
#         0.48509015, 0.49792371, 0.7175596 , 0.87573426, 0.1407123 ,
#         0.29745509, 0.87060806, 0.22526564, 0.08287664, 0.18748559]),
#  array([5.80569045e-04, 2.74835326e-02, 4.56451974e-01, 9.63070195e-01,
#         7.24314027e-01, 9.16089675e-01, 1.68436666e-01, 9.90941392e-01,
#         7.86936804e-01, 6.30215806e-01, 8.87152222e-02, 8.06443976e-01,
#         1.93150486e-01, 1.01233371e-01, 7.22573697e-01, 4.08857031e-01,
#         4.19410562e-01, 3.72344413e-01, 3.11732845e-01, 7.93433309e-01,
#         6.58055965e-01, 1.43510344e-01, 9.22452702e-02, 8.25658366e-01,
#         9.32739107e-01]))

# %%
plt.scatter(x,y ,c = 'r')

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.random.rand(50)

# %%
x
# Out:
# array([0.91800509, 0.84586191, 0.52283731, 0.37387367, 0.26555209,
#        0.72811574, 0.59747308, 0.83306435, 0.39742127, 0.68262745,
#        0.93670555, 0.73869702, 0.85661251, 0.41700111, 0.56537839,
#        0.07872026, 0.29577005, 0.01347918, 0.7817041 , 0.78498113,
#        0.82631804, 0.40603067, 0.26592945, 0.42175676, 0.44301935,
#        0.96351326, 0.96561292, 0.13126156, 0.52924828, 0.12836224,
#        0.60039604, 0.07173156, 0.49052537, 0.28849583, 0.76386213,
#        0.97237313, 0.03591367, 0.36083056, 0.92035625, 0.08023218,
#        0.15774362, 0.04782684, 0.31325727, 0.40147463, 0.44505972,
#        0.72137234, 0.17495989, 0.42097075, 0.90953143, 0.08123356])

# %%
y=np.random.rand(50)

# %%
y
# Out:
# array([0.63038524, 0.37996289, 0.90628039, 0.09130117, 0.05598117,
#        0.76010856, 0.65943181, 0.25143186, 0.08857908, 0.19748663,
#        0.3629484 , 0.11378513, 0.99978229, 0.20741979, 0.27917138,
#        0.78703773, 0.28292018, 0.22315901, 0.89645101, 0.01878579,
#        0.22805111, 0.59079533, 0.29767599, 0.371579  , 0.93392321,
#        0.5893681 , 0.59992426, 0.51829635, 0.30778506, 0.66694214,
#        0.96792763, 0.45959814, 0.58032449, 0.19361271, 0.52281459,
#        0.12797583, 0.58070326, 0.25885212, 0.11135534, 0.15058754,
#        0.36749145, 0.84170289, 0.1576491 , 0.65959939, 0.67052498,
#        0.41871008, 0.0083502 , 0.84003708, 0.64173181, 0.24544224])

# %%
plt.scatter(x,y)
plt.title("time_pass")
# Out:
# Text(0.5, 1.0, 'time_pass')

# %%
x=np.linspace(0,10,50)

# %%
y=np.sin(x)

# %%
plt.plot(x,y)
plt.show()
